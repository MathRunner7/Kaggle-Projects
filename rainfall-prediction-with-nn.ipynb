# %% [markdown]
# # Data Import

# %%
# Import Libraries
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Import train and test data
train = pd.read_csv("/kaggle/input/playground-series-s5e3/train.csv")
test = pd.read_csv("/kaggle/input/playground-series-s5e3/test.csv").fillna(0)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2190 entries, 0 to 2189
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             2190 non-null   int64
#  1   day            2190 non-null   int64
#  2   pressure       2190 non-null   float64
#  3   maxtemp        2190 non-null   float64
#  4   temparature    2190 non-null   float64
#  5   mintemp        2190 non-null   float64
#  6   dewpoint       2190 non-null   float64
#  7   humidity       2190 non-null   float64
#  8   cloud          2190 non-null   float64
#  9   sunshine       2190 non-null   float64
#  10  winddirection  2190 non-null   float64
#  11  windspeed      2190 non-null   float64
#  12  rainfall       2190 non-null   int64
# dtypes: float64(10), int64(3)
# memory usage: 222.5 KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             730 non-null    int64
#  1   day            730 non-null    int64
#  2   pressure       730 non-null    float64
#  3   maxtemp        730 non-null    float64
#  4   temparature    730 non-null    float64
#  5   mintemp        730 non-null    float64
#  6   dewpoint       730 non-null    float64
#  7   humidity       730 non-null    float64
#  8   cloud          730 non-null    float64
#  9   sunshine       730 non-null    float64
#  10  winddirection  730 non-null    float64
#  11  windspeed      730 non-null    float64
# dtypes: float64(10), int64(2)
# memory usage: 68.6 KB

# %%
train.sample(5)
# Out:
#         id  day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  \
# 1566  1566  107    1013.3     29.8         27.6     26.6      24.4      90.0
# 1005  1005  276    1016.9     24.8         22.9     20.6      22.2      92.0
# 812    812   83    1008.2     25.9         22.0     21.5      20.6      88.0
# 315    315  316    1017.9     20.5         20.4     19.9      18.1      88.0
# 42      42   43    1013.1     21.4         20.9     19.4      17.8      83.0
#
#       cloud  sunshine  winddirection  windspeed  rainfall
# 1566   80.0       3.5          240.0       18.4         1
# 1005   88.0       0.0           70.0       50.6         1
# 812    84.0       3.2           20.0       24.2         1
# 315    83.0       3.1           70.0       22.9         1
# 42     88.0       0.0           30.0       20.8         1

# %% [markdown]
# # EDA

# %%
# Basic overview of numerical data
train.describe()
# Out:
#                 id          day     pressure      maxtemp  temparature  \
# count  2190.000000  2190.000000  2190.000000  2190.000000  2190.000000
# mean   1094.500000   179.948402  1013.602146    26.365799    23.953059
# std     632.342866   105.203592     5.655366     5.654330     5.222410
# min       0.000000     1.000000   999.000000    10.400000     7.400000
# 25%     547.250000    89.000000  1008.600000    21.300000    19.300000
# 50%    1094.500000   178.500000  1013.000000    27.800000    25.500000
# 75%    1641.750000   270.000000  1017.775000    31.200000    28.400000
# max    2189.000000   365.000000  1034.600000    36.000000    31.500000
#
#            mintemp     dewpoint     humidity        cloud     sunshine  \
# count  2190.000000  2190.000000  2190.000000  2190.000000  2190.000000
# mean     22.170091    20.454566    82.036530    75.721918     3.744429
# std       5.059120     5.288406     7.800654    18.026498     3.626327
# min       4.000000    -0.300000    39.000000     2.000000     0.000000
# 25%      17.700000    16.800000    77.000000    69.000000     0.400000
# 50%      23.850000    22.150000    82.000000    83.000000     2.400000
# 75%      26.400000    25.000000    88.000000    88.000000     6.800000
# max      29.800000    26.700000    98.000000   100.000000    12.100000
#
#        winddirection    windspeed     rainfall
# count    2190.000000  2190.000000  2190.000000
# mean      104.863151    21.804703     0.753425
# std        80.002416     9.898659     0.431116
# min        10.000000     4.400000     0.000000
# 25%        40.000000    14.125000     1.000000
# 50%        70.000000    20.500000     1.000000
# 75%       200.000000    27.900000     1.000000
# max       300.000000    59.500000     1.000000

# %% [markdown]
# ## Visualization

# %%
# Import visualization libraries
import plotly.graph_objects as go
import seaborn as sns

# %%
# Univariate Analysis
fig = go.Figure()
fig.add_traces([go.Box(y=train['maxtemp'], name='Max Temperature'),go.Violin(y=train['maxtemp'], name='Max Temperature')])
fig.add_traces([go.Violin(y=train['temparature'], name='Avg Temperature'),go.Box(y=train['temparature'], name='Avg Temperature')])
fig.add_traces([go.Violin(y=train['mintemp'], name='Min Temperature'),go.Box(y=train['mintemp'], name='Min Temperature')])
fig.update_layout(title='Min, Avg and Max temperature distribution', title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id
 'dewpoint', 'humidity', 'cloud', 'sunshine', 'winddirection','windspeed']
#pair = sns.pairplot(data=train, hue='rainfall', diag_kind='kde', x_vars=cols, y_vars=cols)
#pair.map_lower(sns.kdeplot, levels=10, color=".2")

# %%
# Pie chart for rainfall days distribution
fig=go.Figure()
fig.add_trace(go.Pie(labels=train.rainfall.value_counts().index, values=train.rainfall.value_counts().values))
fig.update_layout(title='Rainfall days proportion', title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cfc487be-1145-4117-ab90-c9fc8a115e13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfc487be-1145-4117-ab90-c9fc8a115e13")) {                    Plotly.newPlot(                        "cfc487be-1145-4117-ab90-c9fc8a115e13",                        [{"labels":[1,0],"values":[1650,540],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d", ...

# %%
# Correlation Heatmap
fig = go.Figure()
fig.add_trace(go.Heatmap(z=train.corr(), x=train.corr().columns, y=train.corr().index))
fig.update_layout(width=800, height=800, title='Features correlation Heatmap', title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6d941b40-c374-45ac-80bc-fe26c1c528f1" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d941b40-c374-45ac-80bc-fe26c1c528f1")) {                    Plotly.newPlot(                        "6d941b40-c374-45ac-80bc-fe26c1c528f1",                        [{"x":["id","day","pressure","maxtemp","temparature","mintemp","dewpoint","humidity","cloud","sunshine","winddirection","windspeed","rainfall"],"y":["id","day","pressure","maxtemp","temparature","mintemp","dewpoint","humidity","cloud","sunshine","winddirection","windspeed","rainfall"],"z":[[1.0,0.1530651187027479,-0.008234737322965868,0.012589910302369937,0.01430651753726111,0.01870778127998063,0.0067968527932147985,-0.029042329409200023,0.002226191898607328,-0.0030222293962771595,-0.004222734482296381,0.020167290905885978,0.03367407787923572],[0.1530651187027479,1.0,0.005337193138240335,0.14629426101770004,0.15359022057723332,0.16147529422007906,0.1379288312497599,-0.07404785296724331,-0.04817497682010791,0.06093612848077947,0.024799666861023348,-0.00019853252908556615,-0.00046194720464825016],[-0.008234737322965868,0.005337193138240335,1.0,-0.8004990246459617,-0.8165308522258306,-0.8144533378715528,-0.8170079548796162,-0.11994925327478936,0.09859980834601648,-0.25716343880964854,-0.6432928564259199,0.26601246699009656,-0.049885545226120716],[0.012589910302369937,0.14629426101770004,-0.8004990246459617,1.0,0.9829317560786646,0.9655287301769214,0.9067025850131254,-0.0726149423789511,-0.2890465176155402,0.452387476432918,0.6622348202361671,-0.35416794639147287,-0.07930352093398019],[0.01430651753726111,0.15359022057723332,-0.8165308522258306,0.9829317560786646,1.0,0.9871499535596853,0.9336174104477594,-0.025016217270740736,-0.24935465171077129,0.41401860989504174,0.6689626833961513,-0.342261882782693,-0.04966019512336498],[0.01870778127998063,0.16147529422007906,-0.8144533378715528,0.9655287301769214,0.9871499535596853,1.0,0.9413416333402178,0.009891373711476059,-0.21939878213288905,0.37949654947410144,0.6638282480785059,-0.32887050838698717,-0.026841467913443776],[0.0067968527932147985,0.1379288312497599,-0.8170079548796162,0.9067025850131254,0.9336174104477594,0.9413416333402178,1.0,0.1533897488365542,-0.0884460544616902,0.24967627101284132,0.6430732593027881,-0.3121786831557614,0.08196503691537727],[-0.029042329409200023,-0.07404785296724331,-0.11994925327478936,-0.0726149423789511,-0.025016217270740736,0.009891373711476059,0.1533897488365542,1.0,0.5848543488485729,-0.541591914489114,-0.012430170049434593,0.06228470005935457,0.45421348315559923],[0.002226191898607328,-0.04817497682010791,0.09859980834601648,-0.2890465176155402,-0.24935465171077129,-0.21939878213288905,-0.0884460544616902,0.5848543488485729,1.0,-0.8051284328564674,-0.12708679538851603,0.18469754258865842,0.641191203642084],[-0.0030222293962771595,0.06093612848077947,-0.25716343880964854,0.452387476432918,0.41401860989504174,0.37949654947410144,0.24967627101284132,-0.541591914489114,-0.8051284328564674,1.0,0.27223472599888415,-0.2417518820475742,-0.5552869202009945],[-0.004222734482296381,0.024799666861023348,-0.6432928564259199,0.6622348202361671,0.6689626833961513,0.6638282480785059,0.6430732593027881,-0.012430170049434593,-0.12708679538851603,0.27223472599888415,1.0,-0.19241691314451417,-0.006939121420281692],[0.020167290905885978,-0.00019853252908556615,0.26601246699009656,-0.35416794639147287,-0.342261882782693,-0.32887050838698717,-0.3121786831557614,0.06228470005935457,0.18469754258865842,-0.2417518820475742,-0.19241691314451417,1.0,0.11162459374111884],[0.03367407787923572,-0.00046194720464825016,-0.049885545226120716,-0.07930352093398019,-0.04966019512336498,-0.026841467913443776,0.0819650369153772 ...

# %% [markdown]
# # Data Preperation

# %%
# Feature Selection (Drop unnecessary features)
from sklearn.feature_selection import mutual_info_classif
from statsmodels.stats.outliers_influence import variance_inflation_factor

drop_columns = ['id']

X = train.drop(columns=drop_columns)  # Features
y = np.array(train['rainfall'], dtype=int)                 # Target variable

# Compute mutual information
mi_scores = mutual_info_classif(X, y, discrete_features='auto')

# Show results
mi_df = pd.DataFrame({'Feature': X.columns, 'MI Score': mi_scores})
mi_df = mi_df.sort_values(by="MI Score", ascending=False)

# Compute VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(pd.merge(mi_df, vif_data, how='left'))
# Out:
#           Feature  MI Score          VIF
# 0        rainfall  0.558770     7.328686
# 1           cloud  0.210727    66.948431
# 2        sunshine  0.166272     7.466904
# 3        humidity  0.134510   206.110472
# 4             day  0.064608     4.155342
# 5     temparature  0.021723  1825.813091
# 6        pressure  0.020252   266.904764
# 7         maxtemp  0.019656   751.950327
# 8        dewpoint  0.014750   188.000588
# 9         mintemp  0.014039   919.312192
# 10      windspeed  0.005321     6.837256
# 11  winddirection  0.005178     5.084439

# %%
# Drop temperature column
from sklearn.feature_selection import mutual_info_classif
from statsmodels.stats.outliers_influence import variance_inflation_factor

drop_columns = ['id', 'temparature']

X = train.drop(columns=drop_columns)  # Features
y = np.array(train['rainfall'], dtype=int)                 # Target variable

# Compute mutual information
mi_scores = mutual_info_classif(X, y, discrete_features='auto')

# Show results
mi_df = pd.DataFrame({'Feature': X.columns, 'MI Score': mi_scores})
mi_df = mi_df.sort_values(by="MI Score", ascending=False)

# Compute VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(pd.merge(mi_df, vif_data, how='left'))
# Out:
#           Feature  MI Score         VIF
# 0        rainfall  0.558770    7.327200
# 1           cloud  0.205686   66.912221
# 2        sunshine  0.166734    7.448074
# 3        humidity  0.135515  205.973310
# 4             day  0.068027    4.155181
# 5         mintemp  0.025417  474.028548
# 6        dewpoint  0.021524  183.619084
# 7         maxtemp  0.011464  410.567126
# 8       windspeed  0.003773    6.836908
# 9   winddirection  0.003090    5.077042
# 10       pressure  0.000843  265.556066

# %%
# Drop mintemp, maxtemp column
from sklearn.feature_selection import mutual_info_classif
from statsmodels.stats.outliers_influence import variance_inflation_factor

drop_columns = ['id', 'temparature', 'mintemp', 'maxtemp']

X = train.drop(columns=drop_columns)  # Features
y = np.array(train['rainfall'], dtype=int)                 # Target variable

# Compute mutual information
mi_scores = mutual_info_classif(X, y, discrete_features='auto')

# Show results
mi_df = pd.DataFrame({'Feature': X.columns, 'MI Score': mi_scores})
mi_df = mi_df.sort_values(by="MI Score", ascending=False)

# Compute VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(pd.merge(mi_df, vif_data, how='left'))
# Out:
#          Feature  MI Score         VIF
# 0       rainfall  0.559226    7.318586
# 1          cloud  0.214569   66.791490
# 2       sunshine  0.158011    7.072827
# 3       humidity  0.143853  196.078688
# 4            day  0.076700    4.111951
# 5       dewpoint  0.025019   34.550688
# 6       pressure  0.007629  213.043517
# 7      windspeed  0.007625    6.749191
# 8  winddirection  0.003898    4.855205

# %%
# Drop pressure column
from sklearn.feature_selection import mutual_info_classif
from statsmodels.stats.outliers_influence import variance_inflation_factor

drop_columns = ['id', 'temparature', 'mintemp', 'maxtemp', 'pressure']

X = train.drop(columns=drop_columns)  # Features
y = np.array(train['rainfall'], dtype=int)                 # Target variable

# Compute mutual information
mi_scores = mutual_info_classif(X, y, discrete_features='auto')

# Show results
mi_df = pd.DataFrame({'Feature': X.columns, 'MI Score': mi_scores})
mi_df = mi_df.sort_values(by="MI Score", ascending=False)

# Compute VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(pd.merge(mi_df, vif_data, how='left'))
# Out:
#          Feature  MI Score        VIF
# 0       rainfall  0.560368   7.207907
# 1          cloud  0.216812  58.794282
# 2       sunshine  0.166390   4.535855
# 3       humidity  0.131123  86.209390
# 4            day  0.076274   4.009019
# 5       dewpoint  0.016352  34.513120
# 6      windspeed  0.006395   6.414420
# 7  winddirection  0.000000   4.828891

# %%
# Split data into train + validation and then scale them along with test data
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import StandardScaler

drop_columns = ['id', 'temparature', 'mintemp', 'maxtemp', 'pressure', 'rainfall']
X = train.drop(columns=drop_columns)
y = np.array(train['rainfall'], dtype=int)

X_train, X_val, y_train, y_val = tts(X, y, test_size=0.2)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

X_test = test.drop(columns=drop_columns, errors='ignore')
X_test = scaler.transform(X_test)

# %%
# Get Basic idea of class weights to tackle problem of imballancing
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(class_weight='balanced', 
                                     classes=np.unique(y_train), 
                                     y=y_train)

class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}
class_weights_dict
# Out:
# {0: 2.046728971962617, 1: 0.6616314199395771}

# %% [markdown]
# # Model Training

# %%
# Import model traing package
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, BatchNormalization, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
X_train.shape
# Out:
# (1752, 7)

# %%
# Define Model Layers
inputs = Input(shape=(X_train.shape[1], ), name='InputLayer')

layer1 = Dense(128, activation='relu', name='Layer1', kernel_regularizer=regularizers.l1(0.001))(inputs)
layer1 = BatchNormalization(scale=False)(layer1)
layer1 = Dropout(0.3)(layer1)

layer2 = Dense(64, activation='leaky_relu', name='Layer2', kernel_regularizer=regularizers.l1(0.001))(layer1)
layer2 = BatchNormalization()(layer2)

layer3 = Dense(32, activation='leaky_relu', name='Layer3', kernel_regularizer=regularizers.l1(0.001))(layer2)
layer3 = BatchNormalization()(layer3)

layer4 = Dense(16, activation='leaky_relu', name='Layer4', kernel_regularizer=regularizers.l1(0.001))(layer3)
layer4 = BatchNormalization()(layer4)

layer5 = Dense(8, activation='leaky_relu', name='Layer5', kernel_regularizer=regularizers.l1(0.001))(layer4)
layer5 = BatchNormalization()(layer5)

layer6 = Dense(4, activation='leaky_relu', name='Layer6', kernel_regularizer=regularizers.l1(0.001))(layer5)
layer6 = BatchNormalization()(layer6)

outputs = Dense(1, activation='sigmoid', name='OutputLayer')(layer6)

model = Model(inputs=inputs, outputs=outputs)

# Define the callback to early stopping and save the best model based on validation loss
early_stopping = EarlyStopping(monitor='val_AUC', patience=5, restore_best_weights=True)
checkpoint = ModelCheckpoint(filepath='best_model.keras',
                             monitor='val_AUC',
                             save_best_only=True,
                             mode='max',
                             verbose=2)

# Define model compilation parameters
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy', 'AUC', 'precision', 'recall'])

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ InputLayer (InputLayer)              │ (None, 7)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Layer1 (Dense)                       │ (None, 128)                 │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 128)                 │             384 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Layer2 (Dense)                       │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Layer3 (Dense)                       │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 32)                  │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Layer4 (Dense)                       │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 16)                  │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Layer5 (Dense)                       │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8)                   │              32 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ Layer6 (Dense)                       │ (None, 4)                   │              36 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 4)                   │              16 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ OutputLayer (Dense)                  │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,945 (50.57 KB)
#  Trainable params: 12,441 (48.60 KB)
#  Non-trainable params: 504 (1.97 KB)

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, 
    to_file='model.png', 
    show_shapes=True, show_layer_names=True)

# %%
# Train Model
history = model.fit(x=X_train, y=y_train, epochs=200, batch_size=128, verbose=1,
                    validation_data=(X_val, y_val),
                    class_weight={0: 1.966338028169014, 1: 0.9606334841628959},
                    callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - AUC: 0.5948 - accuracy: 0.5738 - loss: 2.2057 - precision: 0.8082 - recall: 0.5618
# Epoch 1: val_AUC improved from -inf to 0.83492, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 13s 434ms/step - AUC: 0.6027 - accuracy: 0.5782 - loss: 2.1933 - precision: 0.8124 - recall: 0.5652 - val_AUC: 0.8349 - val_accuracy: 0.8288 - val_loss: 1.8485 - val_precision: 0.8277 - val_recall: 0.9724
# Epoch 2/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.7946 - accuracy: 0.7109 - loss: 1.9512 - precision: 0.9014 - recall: 0.6809
# Epoch 2: val_AUC improved from 0.83492 to 0.86163, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8397 - accuracy: 0.7445 - loss: 1.8399 - precision: 0.9279 - recall: 0.7135 - val_AUC: 0.8616 - val_accuracy: 0.8539 - val_loss: 1.8086 - val_precision: 0.8522 - val_recall: 0.9724
# Epoch 3/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - AUC: 0.8193 - accuracy: 0.7656 - loss: 1.8022 - precision: 0.9268 - recall: 0.7600
# Epoch 3: val_AUC improved from 0.86163 to 0.86274, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8549 - accuracy: 0.7784 - loss: 1.7703 - precision: 0.9272 - recall: 0.7689 - val_AUC: 0.8627 - val_accuracy: 0.8516 - val_loss: 1.7730 - val_precision: 0.8462 - val_recall: 0.9785
# Epoch 4/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.7760 - accuracy: 0.6875 - loss: 1.8471 - precision: 0.9000 - recall: 0.6923
# Epoch 4: val_AUC improved from 0.86274 to 0.86400, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8630 - accuracy: 0.7791 - loss: 1.7449 - precision: 0.9220 - recall: 0.7725 - val_AUC: 0.8640 - val_accuracy: 0.8425 - val_loss: 1.7332 - val_precision: 0.8391 - val_recall: 0.9755
# Epoch 5/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8282 - accuracy: 0.7422 - loss: 1.7616 - precision: 0.9241 - recall: 0.7300
# Epoch 5: val_AUC did not improve from 0.86400
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8772 - accuracy: 0.7989 - loss: 1.6962 - precision: 0.9292 - recall: 0.7956 - val_AUC: 0.8612 - val_accuracy: 0.8447 - val_loss: 1.6943 - val_precision: 0.8413 - val_recall: 0.9755
# Epoch 6/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - AUC: 0.8944 - accuracy: 0.8281 - loss: 1.6493 - precision: 0.9540 - recall: 0.8218
# Epoch 6: val_AUC improved from 0.86400 to 0.87099, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8860 - accuracy: 0.8313 - loss: 1.6578 - precision: 0.9310 - recall: 0.8391 - val_AUC: 0.8710 - val_accuracy: 0.8447 - val_loss: 1.6534 - val_precision: 0.8413 - val_recall: 0.9755
# Epoch 7/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.8930 - accuracy: 0.8281 - loss: 1.6178 - precision: 0.9333 - recall: 0.8400
# Epoch 7: val_AUC did not improve from 0.87099
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8819 - accuracy: 0.8301 - loss: 1.6366 - precision: 0.9282 - recall: 0.8422 - val_AUC: 0.8703 - val_accuracy: 0.8516 - val_loss: 1.6153 - val_precision: 0.8499 - val_recall: 0.9724
# Epoch 8/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - AUC: 0.9228 - accuracy: 0.8516 - loss: 1.5605 - precision: 0.9556 - recall: 0.8515
# Epoch 8: val_AUC did not improve from 0.87099
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9022 - accuracy: 0.8387 - loss: 1.5848 - precision: 0.9311 - recall: 0.8510 - val_AUC: 0.8629 - val_accuracy: 0.8516 - val_loss: 1.5778 - val_precision: 0.8480 - val_recall: 0.9755
# Epoch 9/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - AUC: 0.9083 - accuracy: 0.8672 - loss: 1.5516 - precision: 0.9551 - recall: 0.8673
# Epoch 9: val_AUC did not improve from 0.87099
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8983 - accuracy: 0.8528 - loss: 1.5625 - precision: 0.9251 - recall: 0.8736 - val_AUC: 0.8699 - val_accuracy: 0.8516 - val_loss: 1.5384 - val_precision: 0.8480 - val_recall: 0.9755
# Epoch 10/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - AUC: 0.9248 - accuracy: 0.8516 - loss: 1.5206 - precision: 0.9462 - recall: 0.8627
# Epoch 10: val_AUC improved from 0.87099 to 0.87505, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8962 - accuracy: 0.8462 - loss: 1.5473 - precision: 0.9269 - recall: 0.8669 - val_AUC: 0.8751 - val_accuracy: 0.8493 - val_loss: 1.5045 - val_precision: 0.8495 - val_recall: 0.9693
# Epoch 11/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - AUC: 0.9127 - accuracy: 0.8594 - loss: 1.4965 - precision: 0.9556 - recall: 0.8600
# Epoch 11: val_AUC improved from 0.87505 to 0.87804, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.8973 - accuracy: 0.8489 - loss: 1.5230 - precision: 0.9236 - recall: 0.8742 - val_AUC: 0.8780 - val_accuracy: 0.8584 - val_loss: 1.4678 - val_precision: 0.8607 - val_recall: 0.9663
# Epoch 12/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - AUC: 0.8938 - accuracy: 0.8516 - loss: 1.5067 - precision: 0.9032 - recall: 0.8936
# Epoch 12: val_AUC improved from 0.87804 to 0.87831, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8867 - accuracy: 0.8450 - loss: 1.5089 - precision: 0.9199 - recall: 0.8704 - val_AUC: 0.8783 - val_accuracy: 0.8584 - val_loss: 1.4352 - val_precision: 0.8626 - val_recall: 0.9632
# Epoch 13/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - AUC: 0.9463 - accuracy: 0.8750 - loss: 1.3708 - precision: 0.9667 - recall: 0.8700
# Epoch 13: val_AUC improved from 0.87831 to 0.88361, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - AUC: 0.9042 - accuracy: 0.8480 - loss: 1.4531 - precision: 0.9221 - recall: 0.8720 - val_AUC: 0.8836 - val_accuracy: 0.8630 - val_loss: 1.4014 - val_precision: 0.8694 - val_recall: 0.9601
# Epoch 14/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - AUC: 0.9126 - accuracy: 0.8203 - loss: 1.4577 - precision: 0.8824 - recall: 0.8523
# Epoch 14: val_AUC did not improve from 0.88361
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9007 - accuracy: 0.8455 - loss: 1.4379 - precision: 0.9181 - recall: 0.8715 - val_AUC: 0.8836 - val_accuracy: 0.8676 - val_loss: 1.3697 - val_precision: 0.8743 - val_recall: 0.9601
# Epoch 15/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - AUC: 0.9003 - accuracy: 0.8828 - loss: 1.4289 - precision: 0.9239 - recall: 0.9140
# Epoch 15: val_AUC did not improve from 0.88361
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8988 - accuracy: 0.8631 - loss: 1.4158 - precision: 0.9238 - recall: 0.8915 - val_AUC: 0.8771 - val_accuracy: 0.8630 - val_loss: 1.3454 - val_precision: 0.8715 - val_recall: 0.9571
# Epoch 16/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - AUC: 0.8820 - accuracy: 0.8281 - loss: 1.4601 - precision: 0.8989 - recall: 0.8602
# Epoch 16: val_AUC did not improve from 0.88361
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.8951 - accuracy: 0.8478 - loss: 1.4057 - precision: 0.9176 - recall: 0.8756 - val_AUC: 0.8719 - val_accuracy: 0.8607 - val_loss: 1.3188 - val_precision: 0.8670 - val_recall: 0.9601
# Epoch 17/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - AUC: 0.8861 - accuracy: 0.8438 - loss: 1.3928 - precision: 0.9355 - recall: 0.8614
# Epoch 17: val_AUC did not improve from 0.88361
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9062 - accuracy: 0.8521 - loss: 1.3592 - precision: 0.9280 - recall: 0.8755 - val_AUC: 0.8723 - val_accuracy: 0.8607 - val_loss: 1.2892 - val_precision: 0.8691 - val_recall: 0.9571
# Epoch 18/200
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - AUC: 0.9358 - accuracy: 0.8828 - loss: 1.2695 - precision: 0.9405 - recall: 0.8876
# Epoch 18: val_AUC did not improve from 0.88361
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - AUC: 0.9108 - accuracy: 0.8639 - loss: 1.3273 - precision: 0.9229 - recall: 0.8918 - val_AUC: 0.8593 - val_accuracy: 0.8653 - val_loss: 1.2717 - val_precision: 0.8638 - val_recall: 0.9724

# %% [markdown]
# # Test Data Prediction and Submission

# %%
from tensorflow.keras.models import load_model

# Load the best model
best_model = load_model('best_model.keras')
best_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'AUC', 'precision', 'recall'])

# %%
from sklearn.metrics import roc_curve

y_pred_prob = best_model.predict(X_val)
# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)

# Find the optimal threshold (maximizing TPR - FPR)
optimal_idx = np.argmax(tpr - fpr)
optimal_threshold = thresholds[optimal_idx]

print(f"Optimal Threshold: {optimal_threshold:.4f}")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# Optimal Threshold: 0.6593

# %%
result = pd.DataFrame({'id':test['id'],'rainfall':(best_model.predict(X_test).flatten())})
result.to_csv('submission.csv', index=False)
print(result.head())
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#      id  rainfall
# 0  2190  0.771170
# 1  2191  0.780262
# 2  2192  0.669693
# 3  2193  0.302169
# 4  2194  0.239524

# %%
result.isna().sum()
# Out:
# id          0
# rainfall    0
# dtype: int64
